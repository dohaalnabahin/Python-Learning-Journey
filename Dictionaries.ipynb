# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Python-Learning-Journey/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a dictionary of states and capitals
state_caps = {'Ohio':'Columbus', 'Alabama':'Montgomery', 'Washington':'Olympia'}
# look up a value using the key
print(state_caps['Washington'])
# Out:
# Olympia

# %%
# Add a new key/value pair
state_caps['Utah'] = 'Salt Lake'
print(state_caps)
# Out:
# {'Ohio': 'Columbus', 'Alabama': 'Montgomery', 'Washington': 'Olympia', 'Utah': 'Salt Lake'}

# %%
# Change the value associated with a key
state_caps['Utah'] = 'Salt Lake City'
state_caps['palestine'] = 'jureslam'
state_caps['egypt'] = 'cairo'
state_caps['jorden'] = 'oman'
state_caps['united arab emirate'] = 'abu dabi'

print(state_caps)
# Out:
# {'Alabama': 'Montgomery', 'Washington': 'Olympia', 'Utah': 'Salt Lake City', 'palestine': 'jureslam', 'egypt': 'cairo', 'jorden': 'oman', 'united arab emirate': 'abu dabi'}

# %%
# removing a key value pair from the dict with .pop()
state_caps.pop('Ohio')
print(f'After popping, the dictionary now looks like this: {state_caps}.')
# Out:
# After popping, the dictionary now looks like this: {'Alabama': 'Montgomery', 'Washington': 'Olympia', 'Utah': 'Salt Lake City'}.

# %%
# create list of states
states_list = ['Indiana', 'Kentucky', 'Texas', 'Idaho']
# create list of matching capitals
caps_list = ['Indianapolis', 'Frankfort', 'Austin', 'Boise']

# %%
# combine the two lists into a dict
zip_dict = dict(zip(states_list, caps_list))
print(f'We created the following dictionary: {zip_dict}')
# Out:
# We created the following dictionary: {'Indiana': 'Indianapolis', 'Kentucky': 'Frankfort', 'Texas': 'Austin', 'Idaho': 'Boise'}

# %%
# Add one dictionary to another
state_caps.update(zip_dict)
print(state_caps)
# Out:
# {'Alabama': 'Montgomery', 'Washington': 'Olympia', 'Utah': 'Salt Lake City', 'palestine': 'jureslam', 'egypt': 'cairo', 'jorden': 'oman', 'united arab emirate': 'abu dabi', 'Indiana': 'Indianapolis', 'Kentucky': 'Frankfort', 'Texas': 'Austin', 'Idaho': 'Boise'}
