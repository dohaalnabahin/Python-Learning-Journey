# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Python-Learning-Journey/blob/main/Functional_Programming_and_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell to see what value the function returns
max(5, 7)
# Out:
# 7

# %%
# Run this cell to return the minimum of 3 and 2.
min(3, 2)
# Out:
# 2

# %%
# Run this cell to return the maximum of the minimum of 10 and 3 and the minimum of 5 and 7
max(min(10,3), min(5,7))
# Out:
# 5

# %%
# Run this cell to return a lower case string
txt = 'Hello'
txt.lower()
# Out:
# 'hello'

# %%
# Run this cell to return an upper case string
txt.upper()
# Out:
# 'HELLO'

# %%
# replace h with j in the string
txt.replace('H', 'j')
# Out:
# 'jello'

# %%
word_list = ['this', 'is', 'a', 'list', 'of', 'strings']
random_list = [12, 'frog', ['this','is','a','list','in','a','list'], True, 3.14]
print(word_list)
print(random_list)
# Out:
# ['this', 'is', 'a', 'list', 'of', 'strings']
# [12, 'frog', ['this', 'is', 'a', 'list', 'in', 'a', 'list'], True, 3.14]

# %%
# use .remove() on our word_list
word_list.remove('a')
print(word_list)
# Out:
# ['this', 'is', 'list', 'of', 'strings']

# %%
# Select the first item from the list
print(random_list[0])
# Out:
# 12

# %%
# Negative indexing
print(random_list[-1])
# Out:
# 3.14

# %%
# Combine two lists using the + operator
word_list + random_list
# Out:
# ['this',
#  'is',
#  'list',
#  'of',
#  'strings',
#  12,
#  'frog',
#  ['this', 'is', 'a', 'list', 'in', 'a', 'list'],
#  True,
#  3.14]

# %%
# Demo of tuples of the same data type or mixed data types
integer_tuple = (1,2,3,4,5)
random_tuple = (1, 'horse', integer_tuple, word_list, False)
print(integer_tuple)
print(random_tuple)
# Out:
# (1, 2, 3, 4, 5)
# (1, 'horse', (1, 2, 3, 4, 5), ['this', 'is', 'list', 'of', 'strings'], False)

# %%
# Indexing a range from a tuple
print(random_tuple[0:2])
# Out:
# (1, 'horse')
